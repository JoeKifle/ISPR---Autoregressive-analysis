# %% [markdown]
# ## Autoregressive Model Analysis
#
#
# For this assignment I will be doing autoregressive analysis on the <i>Appliances</i> column of the data set [
# Appliances energy prediction](https://archive.ics.uci.edu/ml/datasets/Appliances+energy+prediction#)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARIMA
from pmdarima.arima import auto_arima
import statsmodels.api as sm
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# I used this function to format my date.
def parser(s):
    return datetime.strptime(s, '%Y-%m-%d %H:%M:%S')

# %%
# Since I only need the date and appliance cols for this task, I only #selected these two.
col_list = ["date", "Appliances"]
rawDf = pd.read_csv('data/energydata_complete.csv',parse_dates=[0], squeeze=True, date_parser=parser,usecols=col_list)

# %% [markdown]
# ### 1. Plotting Data

# %%
rawDf = rawDf.set_index('date')

# %%
rawDf["Appliances"].plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# I am going to draw another plot of the same data over the sample of max temprature during the day because it is little difficult to notice much change in a dense representation of the data.

# %%
highs = rawDf["Appliances"].resample("D").max()
plt.figure(figsize=(20,8))
highs.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# From the graph we can see that the energy usage during winter(Specifically in January) is very high. This is directly related to the cold weather during this season. So, We can assume that there is some seasonality in our data and this violates the non-seasonality property of our timeseries data.

# %% [markdown]
# ## 2. Preprocessing data
#
# We can observe that our data goes up and down a lot and the first thing we do before feeding the data to our model is to <b>NORMALIZE</b> our data.

# %%
# because our data goes from 50 to 1000
avg, dev = rawDf.mean(), rawDf.std()
normalizedDf = (rawDf - avg) / dev

# %%
normalizedDf.head()
# Out:
#                      Appliances
# date
# 2016-01-11 17:00:00   -0.367666
# 2016-01-11 17:10:00   -0.367666
# 2016-01-11 17:20:00   -0.465204
# 2016-01-11 17:30:00   -0.465204
# 2016-01-11 17:40:00   -0.367666

# %%
normalizedDf["Appliances"].plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# Normalizing the data wont change the graph of the data. The graph exactly looks similar to before only the range changes. Mean is centered around zero and sd = 1.

# %% [markdown]
# ### 2. Splitting Time series
#
# // Detail note will be added

# %%
train = normalizedDf[0:11559] # The first three months
test = normalizedDf[11560:]

# %% [markdown]
# ### 3. Training my model
#
# // Detail note will be added

# %%
autoModel =  auto_arima(train,trace=True,max_P=30,max_D=5,max_q=5,seasonal=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=23516.948, Time=18.59 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=33740.821, Time=0.38 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=23916.300, Time=1.07 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=26989.557, Time=1.82 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=33739.365, Time=0.22 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=23720.089, Time=4.55 sec

# %% [markdown]
# Auto ARIMA gave us the best model to use for our data. <br>
# Best model:  ARIMA(3,0,3)(0,0,0)

# %%
model = ARIMA(train, order=(3,0,3))
model_fit = model.fit()
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:             Appliances   No. Observations:                11559
# Model:                     ARMA(3, 3)   Log Likelihood              -11726.798
# Method:                       css-mle   S.D. of innovations              0.667
# Date:                Fri, 19 Mar 2021   AIC                          23469.597
# Time:                        12:28:21   BIC                          23528.439
# Sample:                    01-11-2016   HQIC                         23489.372
#                          - 03-31-2016
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0064      0.038      0.168      0.867      -0.069       0.082
# ar.L1.Appliances     2.3810      0.028     86.376      0.000       2.327       2.435
# ar.L2.Appliances    -1.8821      0.045    -41.672      0.000      -1.971      -1.794
# ar.L3.Appliances     0.4936      0.020     24.709      0.000       0.454       0.533
# ma.L1.Appliances    -1.5880      0.028    -55.842      0.000      -1.644      -1.532
# ma.L2.Appliances     0.4712      0.034     13.880      0.000       0.405       0.538
# ma.L3.Appliances     0.1634      0.015     10.650      0.000       0.133       0.193
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.1829           -0.0256j            1.1832           -0.0034
# AR.2            1.1829           +0.0256j            1.1832            0.0034
# AR.3            1.4472           -0.0000j            1.4472           -0.0000
# MA.1            1.0826           -0.2006j            1.1011           -0.0292
# MA.2            1.0826           +0.2006j            1.1011            0.0292
# MA.3           -5.0496           -0.0000j            5.0496           -0.5000
# -----------------------------------------------------------------------------
# """

# %% [markdown]
# ## Forecasting the future

# %%
history = [x for x in train["Appliances"]]
predictions = list()

# %%
for t in range(len(test)):
    model = ARIMA(history, order=(3,0,3))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    obs = test["Appliances"][t]
    predictions.append(yhat)
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# redicted=-0.417553, expected=-0.562741
# predicted=-0.475080, expected=-0.367666
# predicted=-0.310426, expected=-0.465204
# predicted=-0.420231, expected=-0.465204
# predicted=-0.397765, expected=-0.367666
# predicted=-0.323801, expected=-0.562741
# predicted=-0.490805, expected=-0.465204
# predicted=-0.378799, expected=-0.465204
# predicted=-0.399335, expected=-0.465204
# predicted=-0.393681, expected=-0.562741
# predicted=-0.470462, expected=-0.367666
# predicted=-0.299976, expected=-0.465204
# predicted=-0.409696, expected=-0.367666
# predicted=-0.309516, expected=-0.465204
# predicted=-0.404855, expected=-0.562741
# predicted=-0.461643, expected=-0.465204
# predicted=-0.372536, expected=-0.660278
# predicted=-0.544367, expected=-0.757816
# predicted=-0.588706, expected=-0.562741
# predicted=-0.428632, expected=-0.562741
# predicted=-0.464088, expected=-0.270129
# predicted=-0.229239, expected=-0.465204
# predicted=-0.431999, expected=-0.465204
# predicted=-0.392661, expected=-0.562741
# predicted=-0.477782, expected=-0.465204
# predicted=-0.383988, expected=-0.465204
# predicted=-0.402505, expected=-0.562741
# predicted=-0.475614, expected=-0.367666
# predicted=-0.306507, expected=-0.465204
# predicted=-0.416197, expected=-0.270129
# predicted=-0.238734, expected=-0.465204
# predicted=-0.425626, expected=-0.465204
# predicted=-0.385877, expected=-0.465204
# predicted=-0.391252, expected=-0.465204
# predicted=-0.388134, expected=-0.562741
# predicted=-0.464321, expected=-0.465204
# predicted=-0.371389, expected=-0.367666
# predicted=-0.312372, expected=-0.562741
# predicted=-0.477928, expected=-0.562741
in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-64-fc9bfdea854b>", line 3, in <module>
#     model_fit = model.fit()
#   File "/opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py", line 1016, in fit
#     start_params = self._fit_start_params((k_ar, k_ma, k), method,
#   File "/opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py", line 608, in _fit_start_params
#     start_params = self._fit_start_params_hr(order, start_ar_lags)
#   File "/opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py", line 541, in _fit_start_params_hr
#     mod = ar_select_order(endog, maxlag, trend='n',
#   File "/opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py", line 2703, in ar_select_order
#     ics.append((0, ic_no_data()))
#   File "/opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py", line 2691, in ic_no_data
#     llf = OLS.loglike(mod, np.empty(0))
#   File "/opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/regression/linear_model.py", line 900, in loglike
#     ssr = np.sum(resid**2)
#   File "<__array_function__ internals>", line 5, in sum
#   File "/opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 2247, in sum
#     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#   File "/opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 87, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/opt/anaconda3/envs/nlpPisa2020/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/opt/anaconda3/envs/nlpPisa2020/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/opt/anaconda3/envs/nlpPisa2020/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/opt/anaconda3/envs/nlpPisa2020/lib/python3.8/inspect.py", line 745, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-64-fc9bfdea854b> in <module>
#       2     model = ARIMA(history, order=(3,0,3))
# ----> 3     model_fit = model.fit()
#       4     output = model_fit.forecast()
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#    1015         else:  # estimate starting parameters
# -> 1016             start_params = self._fit_start_params((k_ar, k_ma, k), method,
#    1017                                                   start_ar_lags)
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py in _fit_start_params(self, order, method, start_ar_lags)
#     607
# --> 608             start_params = self._fit_start_params_hr(order, start_ar_lags)
#     609             if self.transparams:
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py in _fit_start_params_hr(self, order, start_ar_lags)
#     540                         maxlag = nobs - 1
# --> 541                     mod = ar_select_order(endog, maxlag, trend='n',
#     542                                           old_names=False).model
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py in ar_select_order(endog, maxlag, ic, glob, trend, seasonal, exog, hold_back, period, missing, old_names)
#    2702             if not np.any(sel):
# -> 2703                 ics.append((0, ic_no_data()))
#    2704                 continue
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py in ic_no_data()
#    2690         )
# -> 2691         llf = OLS.loglike(mod, np.empty(0))
#    2692         res = SimpleNamespace(
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/regression/linear_model.py in loglike(self, params, scale)
#     899             resid -= self.offset
# --> 900         ssr = np.sum(resid**2)
#     901         if scale is None:
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2246
# -> 2247     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2248                           initial=initial, where=where)
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2044                         # in the engines. This should return a list of strings.
# -> 2045                         stb = value._render_traceback_()
#    2046                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2045                         stb = value._render_traceback_()
#    2046                     except Exception:
# -> 2047                         stb = self.InteractiveTB.structured_traceback(etype,
#    2048                                             value, tb, tb_offset=tb_offset)
#    2049
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434         else:
#    1435             self.tb = tb
# -> 1436         return FormattedTB.structured_traceback(
#    1437             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1438
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334         if mode in self.verbose_modes:
#    1335             # Verbose modes need a full traceback
# -> 1336             return VerboseTB.structured_traceback(
#    1337                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1338             )
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1191         """Return a nice text document describing the traceback."""
#    1192
# -> 1193         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1194                                                                tb_offset)
#    1195
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1149
#    1150
# -> 1151         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1152
#    1153         frames = self.format_records(records, last_unique, recursion_repeat)
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
# evaluate forecasts
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# plot forecasts against actual outcomes
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
