# %% [markdown]
# ## Autoregressive Model Analysis
#
#
# For this assignment I will be doing autoregressive analysis on the <i>Appliances</i> column of the data set [
# Appliances energy prediction](https://archive.ics.uci.edu/ml/datasets/Appliances+energy+prediction#)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima.model import ARIMA
from pmdarima.arima import auto_arima
import statsmodels.api as sm
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# I used this function to format my date.
def parser(s):
    return datetime.strptime(s, '%Y-%m-%d %H:%M:%S')
# Date parser for stored model results.
def modelDateparser(s):
    return datetime.strptime(s, '%Y-%m-%d %H:%M')

# %%
# Since I only need the date and appliance cols for this task, I only #selected these two.
col_list = ["date", "Appliances"]
rawDf = pd.read_csv('data/energydata_complete.csv',parse_dates=[0], squeeze=True, date_parser=parser,usecols=col_list)

# %% [markdown]
# ### 1. Plotting Data

# %%
print('-'*60)
print('*** Head of the dataframe ***')
print('-'*60)
print(rawDf.head())
print('-'*60)
print('*** Tail of the dataframe ***')
print('-'*60)
print(rawDf.tail())
# Out:
# ------------------------------------------------------------
# *** Head of the dataframe ***
# ------------------------------------------------------------
#                  date  Appliances
# 0 2016-01-11 17:00:00          60
# 1 2016-01-11 17:10:00          60
# 2 2016-01-11 17:20:00          50
# 3 2016-01-11 17:30:00          50
# 4 2016-01-11 17:40:00          60
# ------------------------------------------------------------
# *** Tail of the dataframe ***
# ------------------------------------------------------------
#                      date  Appliances
# 19730 2016-05-27 17:20:00         100
# 19731 2016-05-27 17:30:00          90
# 19732 2016-05-27 17:40:00         270
# 19733 2016-05-27 17:50:00         420
# 19734 2016-05-27 18:00:00         430

# %%
rawDf = rawDf.set_index('date')

# %%
rawDf["Appliances"].plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# I am going to draw another plot of the same data over the sample of max temprature during the day because it is little difficult to notice much change in a dense representation of the data.

# %%
highs = rawDf["Appliances"].resample("D").max()
plt.figure(figsize=(20,8))
highs.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# From the graph we can see that the energy usage during winter(Specifically in January) is very high. This is directly related to the cold weather during this season. So, We can assume that there is some seasonality in our data and this violates the non-seasonality property of our timeseries data.

# %% [markdown]
# ## 2. Preprocessing data
#
# We can observe that our data goes up and down a lot and the first thing we do before feeding the data to our model is to <b>NORMALIZE</b> our data.

# %%
# because our data goes from 50 to 1000
avg, dev = rawDf.mean(), rawDf.std()
normalizedDf = (rawDf - avg) / dev

# %%
normalizedDf.head()
# Out:
#                      Appliances
# date
# 2016-01-11 17:00:00   -0.367666
# 2016-01-11 17:10:00   -0.367666
# 2016-01-11 17:20:00   -0.465204
# 2016-01-11 17:30:00   -0.465204
# 2016-01-11 17:40:00   -0.367666

# %%
normalizedDf["Appliances"].plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# Normalizing the data wont change the graph of the data. The graph exactly looks similar to before only the range changes. Mean is centered around zero and sd = 1.

# %% [markdown]
# ### 2.1 Checking for stationarity

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
adfuller_test(normalizedDf)
# Out:
# ADF Test Statistic : -21.616378198036188
# p-value : 0.0
# #Lags Used : 11
# Number of Observations Used : 19723

# %%
def adfuller_test(data):
    result=adfuller(data)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )

# %%
plot_acf(normalizedDf)

# %%
# This will remove increasing of data over time.
normalizedDf = normalizedDf.diff(periods=2).dropna()  # dropna

# %%
plot_acf(normalizedDf)

# %% [markdown]
# ### 3. Splitting Time series
#
# // Detail note will be added

# %%
trainArima = normalizedDf[0:11559] # The first three months
trainPhrophet = trainArima
testArima = normalizedDf[11560:]  
testPhrophet = testArima

# %% [markdown]
# ### 4. Training my model
#
# // Detail note will be added

# %%
autoModel =  auto_arima(trainArima,trace=True,max_P=30,max_D=5,max_q=5,seasonal=True,parallel=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=23516.948, Time=19.30 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=33740.821, Time=0.42 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=23916.300, Time=1.09 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=26989.557, Time=2.00 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=33739.365, Time=0.23 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=23720.089, Time=4.66 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=23804.982, Time=6.79 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=23515.113, Time=21.16 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=23516.041, Time=15.11 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=23519.898, Time=11.54 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=23511.650, Time=28.87 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=23515.927, Time=14.08 sec
#  ARIMA(4,0,3)(0,0,0)[0] intercept   : AIC=23514.892, Time=28.29 sec
#  ARIMA(3,0,4)(0,0,0)[0] intercept   : AIC=23513.497, Time=29.87 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=inf, Time=28.88 sec
#  ARIMA(4,0,4)(0,0,0)[0] intercept   : AIC=23524.769, Time=22.03 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=23507.987, Time=13.57 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=23513.949, Time=5.66 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=23513.131, Time=5.69 sec
#  ARIMA(4,0,3)(0,0,0)[0]             : AIC=23511.961, Time=14.54 sec
#  ARIMA(3,0,4)(0,0,0)[0]             : AIC=23510.741, Time=15.27 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=23514.970, Time=3.73 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=27.28 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=23514.389, Time=12.81 sec
#  ARIMA(4,0,4)(0,0,0)[0]             : AIC=23522.797, Time=11.73 sec
#
# Best model:  ARIMA(3,0,3)(0,0,0)[0]
# Total fit time: 344.677 seconds

# %% [markdown]
# Auto ARIMA gave us the best model to use for our data. <br>
# Best model:  ARIMA(3,0,3)(0,0,0)

# %%
model = ARIMA(trainArima, order=(3,0,3))
model_fit = model.fit()
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Appliances   No. Observations:                11559
# Model:                 ARIMA(3, 0, 3)   Log Likelihood              -11746.973
# Date:                Sun, 28 Mar 2021   AIC                          23509.946
# Time:                        21:38:56   BIC                          23568.788
# Sample:                    01-11-2016   HQIC                         23529.721
#                          - 03-31-2016
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0090      0.081      0.111      0.912      -0.150       0.168
# ar.L1          0.4149      0.021     20.094      0.000       0.374       0.455
# ar.L2          0.9519      0.016     59.762      0.000       0.921       0.983
# ar.L3         -0.4169      0.017    -25.137      0.000      -0.449      -0.384
# ma.L1          0.3805      0.020     18.784      0.000       0.341       0.420
# ma.L2         -0.8094      0.016    -49.156      0.000      -0.842      -0.777
# ma.L3         -0.2205      0.007    -30.074      0.000      -0.235      -0.206
# sigma2         0.4469      0.003    173.777      0.000       0.442       0.452
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):            211926.61
# Prob(Q):                              0.89   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.89   Skew:                             2.97
# Prob(H) (two-sided):                  0.00   Kurtosis:                        23.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ## 5. Forecasting the future

# %%
history = [x for x in trainArima["Appliances"]]
predictions = list()

# %% [markdown]
# From the AutoARIMA I got the order of (3,0,0) to be the best estimation. I run the model over the data. I took me 12 hours to get the forecast result upto 28th of Apr 2016. I have also run the model with (3,0,0) and (5,0,0) orders. The result will be displayed below. I saved output to csv file and you can skip excuting the below code and see the result.

# %%
for t in range(len(testArima)):
    model = ARIMA(history, order=(3,0,3))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    obs = testArima["Appliances"][t]
    predictions.append(yhat)
    history.append(obs)
    print('exp=%f, pred=%f' % (obs, yhat))
# Out:
# exp=-0.465204, pred=-0.290579
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-9c06da87708d> in <module>
#       1 for t in range(len(testArima)):
#       2     model = ARIMA(history, order=(3,0,3))
# ----> 3     model_fit = model.fit()
#       4     output = model_fit.forecast()
#       5     yhat = output[0]
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/tsa/arima/model.py in fit(self, start_params, transformed, includes_fixed, method, method_kwargs, gls, gls_kwargs, cov_type, cov_kwds, return_params, low_memory)
#     359                 method_kwargs.setdefault('disp', 0)
#     360
# --> 361                 res = super(ARIMA, self).fit(
#     362                     return_params=return_params, low_memory=low_memory,
#     363                     cov_type=cov_type, cov_kwds=cov_kwds, **method_kwargs)
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/tsa/statespace/mlemodel.py in fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     688                 flags['hessian_method'] = optim_hessian
#     689             fargs = (flags,)
# --> 690             mlefit = super(MLEModel, self).fit(start_params, method=method,
#     691                                                fargs=fargs,
#     692                                                maxiter=maxiter,
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     517         warn_convergence = kwargs.pop('warn_convergence', True)
#     518         optimizer = Optimizer()
# --> 519         xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     520                                                        fargs, kwargs,
#     521                                                        hessian=hess,
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     222
#     223         func = fit_funcs[method]
# --> 224         xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     225                             disp=disp, maxiter=maxiter, callback=callback,
#     226                             retall=retall, full_output=full_output,
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/base/optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     627         func = f
#     628
# --> 629     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     630                                      callback=callback, args=fargs,
#     631                                      bounds=bounds, disp=disp,
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     195             'maxls': maxls}
#     196
# --> 197     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     198                            **opts)
#     199     d = {'grad': res['jac'],
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     259             self._update_x_impl(x)
#     260         self._update_fun()
# --> 261         self._update_grad()
#     262         return self.f, self.g
#     263
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in _update_grad(self)
#     229     def _update_grad(self):
#     230         if not self.g_updated:
# --> 231             self._update_grad_impl()
#     232             self.g_updated = True
#     233
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in update_grad()
#     149                 self._update_fun()
#     150                 self.ngev += 1
# --> 151                 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     152                                            **finite_diff_options)
#     153
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/scipy/optimize/_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     484
#     485         if sparsity is None:
# --> 486             return _dense_difference(fun_wrapped, x0, f0, h,
#     487                                      use_one_sided, method)
#     488         else:
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/scipy/optimize/_numdiff.py in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     555             x = x0 + h_vecs[i]
#     556             dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 557             df = fun(x) - f0
#     558         elif method == '3-point' and use_one_sided[i]:
#     559             x1 = x0 + h_vecs[i]
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/scipy/optimize/_numdiff.py in fun_wrapped(x)
#     435
#     436     def fun_wrapped(x):
# --> 437         f = np.atleast_1d(fun(x, *args, **kwargs))
#     438         if f.ndim > 1:
#     439             raise RuntimeError("`fun` return value has "
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     128         def fun_wrapped(x):
#     129             self.nfev += 1
# --> 130             return fun(x, *args)
#     131
#     132         def update_fun():
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/base/model.py in f(params, *args)
#     499
#     500         def f(params, *args):
# --> 501             return -self.loglike(params, *args) / nobs
#     502
#     503         if method == 'newton':
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/tsa/statespace/mlemodel.py in loglike(self, params, *args, **kwargs)
#     923             kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     924
# --> 925         loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     926
#     927         # Koopman, Shephard, and Doornik recommend maximizing the average
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/tsa/statespace/kalman_filter.py in loglike(self, **kwargs)
#     981         kwargs.setdefault('conserve_memory',
#     982                           MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD)
# --> 983         kfilter = self._filter(**kwargs)
#     984         loglikelihood_burn = kwargs.get('loglikelihood_burn',
#     985                                         self.loglikelihood_burn)
#
# /opt/anaconda3/envs/nlpPisa2020/lib/python3.8/site-packages/statsmodels/tsa/statespace/kalman_filter.py in _filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     904
#     905         # Run the filter
# --> 906         kfilter()
#     907
#     908         return kfilter
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4. RESULT
# ### 4.1 Model 1 (3,0,3)
# I will import the result of the model.

# %%
mod_col = ["date","Appliances","Forecast"]
model303 = pd.read_csv('data/modelPred303.csv',parse_dates=[0], squeeze=True,usecols=mod_col)

# %%
model303Data = model303.set_index("date")

# %%
model303Data.plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ## RMSE

# %%
from sklearn.metrics import mean_squared_error
import math

# %%
y_true = model303Data.reset_index()["Appliances"]
y_forecast = model303Data.reset_index()["Forecast"]

# %%
rmse303 = math.sqrt(mean_squared_error(y_true, y_forecast))

# %%
rmse303
# Out:
# 0.6198170174854203

# %% [markdown]
# ### 4.1 Model 1 (3,0,0)
# I will import the result of the model.

# %%
mod_col = ["date","Appliances","Forecast"]
model300 = pd.read_csv('data/modelPred300.csv',parse_dates=[0], squeeze=True,usecols=mod_col)

# %%
model300Data = model300.set_index("date")

# %%
model300Data.plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### RMSE

# %%
y_true = model300Data.reset_index()["Appliances"]
y_forecast = model300Data.reset_index()["Forecast"]

# %%
rmse300 = math.sqrt(mean_squared_error(y_true, y_forecast))

# %%
rmse300
# Out:
# 0.610734828770234

# %% [markdown]
# ### 4.1 Model 1 (5,0,0)

# %%
mod_col = ["date","Appliances","Forecast"]
model500 = pd.read_csv('data/modelPred500.csv',parse_dates=[0], squeeze=True,usecols=mod_col)

# %%
model500Data = model500.set_index("date")

# %%
model500Data.plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### RMSE

# %%
y_true = model500Data.reset_index()["Appliances"]
y_forecast = model500Data.reset_index()["Forecast"]

# %%
rmse500 = math.sqrt(mean_squared_error(y_true, y_forecast))

# %%
rmse500
# Out:
# 0.6088840736804269

# %% [markdown]
# So, this is better.

# %% [markdown]
# ## Prophet Model

# %%
from fbprophet import Prophet

# %%
#trainPhrophet
#testPhrophet
trainPhrophet.head()
# Out:
#                      Appliances
# date
# 2016-01-11 17:00:00   -0.367666
# 2016-01-11 17:10:00   -0.367666
# 2016-01-11 17:20:00   -0.465204
# 2016-01-11 17:30:00   -0.465204
# 2016-01-11 17:40:00   -0.367666

# %%
trainPhrophet = trainPhrophet.reset_index()
trainPhrophet.rename(columns={'date':'ds','Appliances':'y'},inplace=True)

# %%
trainPhrophet.head()
# Out:
#                    ds         y
# 0 2016-01-11 17:00:00 -0.367666
# 1 2016-01-11 17:10:00 -0.367666
# 2 2016-01-11 17:20:00 -0.465204
# 3 2016-01-11 17:30:00 -0.465204
# 4 2016-01-11 17:40:00 -0.367666

# %% [markdown]
# ## Training Prophet Model

# %%
phrophetModel = Prophet()
phrophetModel.fit(trainPhrophet)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %% [markdown]
# ### Preparing future dates for prediction

# %%
testPhrophet = testPhrophet.reset_index()
future_dates = testPhrophet["date"].to_frame()
future_dates.rename(columns={'date':'ds'},inplace=True)

# %% [markdown]
# #### Forecasting using predict() method.

# %%
forecast = phrophetModel.predict(future_dates)
testPhrophet["Forecast"] = forecast["yhat"]

# %%
testPhrophet = testPhrophet.set_index("date")

# %%
testPhrophet.plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### RESOURCES
# 1. https://www.statsmodels.org/stable/generated/statsmodels.tsa.arima.model.ARIMA.html
# 2. https://alkaline-ml.com/pmdarima/user_guide.html#user-guide
# 3. https://www.kaggle.com/c/web-traffic-time-series-forecasting/discussion/43795
# 4. https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behaviorhttps://www.kaggle.com/timmate/autoregressive-model
# 5. https://www.kaggle.com/manovirat/timeseries-using-prophet-hyperparameter-tuning
